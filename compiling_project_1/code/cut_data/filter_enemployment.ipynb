# %%
import pandas as pd
import numpy as np
import itertools
from builtins import str

# %%
# read data in
file_path = "../../output_data/clean_data/unemployment_clean.csv"
df = pd.read_csv(file_path) 
df
# Out:
#        Date Month  Year  Australia ;  Employed total ;  Persons ;  \
# 0    Jul-91   Jul  1991                                    7583.0
# 1    Aug-91   Aug  1991                                    7620.7
# 2    Sep-91   Sep  1991                                    7713.2
# 3    Oct-91   Oct  1991                                    7638.0
# 4    Nov-91   Nov  1991                                    7614.9
# ..      ...   ...   ...                                       ...
# 348  Jul-20   Jul  2020                                   12475.2
# 349  Aug-20   Aug  2020                                   12572.4
# 350  Sep-20   Sep  2020                                   12583.0
# 351  Oct-20   Oct  2020                                   12756.9
# 352  Nov-20   Nov  2020                                   12909.0
#
#      Australia ;  Employed total ;  > Males ;  \
# 0                                      4398.2
# 1                                      4398.6
# ...

# %%
states = ["Australia", "New South Wales"]
          #"Victoria", "Queensland", "South Australia", "Tasmania", "Northern Territory", "Australian Capital Territory"]

# %%
for state in states:
    state_df = df[["Date","Month","Year",
                    f"{state} ;  Unemployment rate ;  Persons ;",
                   f"{state} ;  Unemployment rate ;  > Males ;",
                    f"{state} ;  Unemployment rate ;  > Females ;"
                   ]]
    
    state.str.replace('> ', '', regex=True)
    state_df.to_csv(f"{state} emp.csv", index = False)
    
       
    #date.append(df[["Date"]])
    #month.append(df[["Month"]])
    #year.append(df[["Year"]])
    #col1.append(df[[f"{state} ;  Unemployment rate ;  Persons ;"]])
    #col2.append(df[[f"{state} ;  Unemployment rate ;  > Males ;"]])
    #col3.append(df[[f"{state} ;  Unemployment rate ;  > Females ;"]])
    
    #emp_df = itertools.chain(['date'], ['month'])
    #emp_list = [date, month, year, col1, col2, col3]
    #test = pd.DataFrame(emp_list)
    
    #emp_merged = pd.merge(emp_list)

#test_df = pd.DataFrame(test)
    #test.to_csv(f"../../output_data/clean_filter/{state}.csv")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-a4c74e45de30> in <module>
#       6                    ]]
#       7
# ----> 8     state.str.replace('> ', '', regex=True)
#       9     state_df.to_csv(f"{state} emp.csv", index = False)
#      10
#
# AttributeError: 'str' object has no attribute 'str'

# %%
# filter data by state australia
df_australia = df[["Date","Month","Year",
             "Australia ;  Unemployment rate ;  Persons ;",
             "Australia ;  Unemployment rate ;  > Males ;",
             "Australia ;  Unemployment rate ;  > Females ;"
          
            ]]
df_cut

# %%
df_australia.to_csv("../../output_data/clean_filter/australia_emp.csv")

# %%
df_nsw = df[["Date","Month","Year",
            "> New South Wales ;  Unemployment rate ;  Persons ;", 
             "> New South Wales ;  Unemployment rate ;  > Males ;", 
             "> New South Wales ;  Unemployment rate ;  > Females ;"
            ]]
df_nsw.to_csv("../../output_data/clean_filter/nsw_emp.csv")
df_nsw

# %%
df_vic = df[["Date","Month","Year",
            "> Victoria ;  Unemployment rate ;  Persons ;", 
             "> Victoria ;  Unemployment rate ;  > Males ;", 
             "> Victoria ;  Unemployment rate ;  > Females ;"
            ]]
df_vic.to_csv("../../output_data/clean_filter/vic_emp.csv")
df_vic

# %%
df_qld = df[["Date","Month","Year",
            "> Queensland ;  Unemployment rate ;  Persons ;", 
             "> Queensland ;  Unemployment rate ;  > Males ;", 
             "> Queensland ;  Unemployment rate ;  > Females ;"
            ]]
df_qld.to_csv("../../output_data/clean_filter/qld_emp.csv")
df_qld

# %%
df_SA = df[["Date","Month","Year",
            "> South Australia ;  Unemployment rate ;  Persons ;", 
             "> South Australia ;  Unemployment rate ;  > Males ;", 
             "> South Australia ;  Unemployment rate ;  > Females ;"
            ]]
df_SA.to_csv("../../output_data/clean_filter/SA_emp.csv")
df_SA

# %%
df_WA = df[["Date","Month","Year",
            "> Western Australia ;  Unemployment rate ;  Persons ;", 
             "> Western Australia ;  Unemployment rate ;  > Males ;", 
             "> Western Australia ;  Unemployment rate ;  > Females ;"
            ]]
df_WA.to_csv("../../output_data/clean_filter/WA_emp.csv")
df_WA

# %%
df_WA = df[["Date","Month","Year",
            "> Western Australia ;  Unemployment rate ;  Persons ;", 
             "> Western Australia ;  Unemployment rate ;  > Males ;", 
             "> Western Australia ;  Unemployment rate ;  > Females ;"
            ]]
df_WA.to_csv("../../output_data/clean_filter/WA_emp.csv")
df_WA

# %%
df_tas = df[["Date","Month","Year",
            "> Tasmania ;  Unemployment rate ;  Persons ;", 
             "> Tasmania ;  Unemployment rate ;  > Males ;", 
             "> Tasmania ;  Unemployment rate ;  > Females ;"
            ]]
df_tas.to_csv("../../output_data/clean_filter/tas_emp.csv")
df_tas

# %%
df_NT = df[["Date","Month","Year",
            "> Northern Territory ;  Unemployment rate ;  Persons ;", 
             "> Northern Territory ;  Unemployment rate ;  > Males ;", 
             "> Northern Territory ;  Unemployment rate ;  > Females ;"
            ]]
df_NT.to_csv("../../output_data/clean_filter/NT_emp.csv")
df_NT

# %%
df_ACT = df[["Date","Month","Year",
            "> Australian Capital Territory ;  Unemployment rate ;  Persons ;", 
             "> Australian Capital Territory ;  Unemployment rate ;  > Males ;", 
             "> Australian Capital Territory ;  Unemployment rate ;  > Females ;"
            ]]
df_ACT.to_csv("../../output_data/clean_filter/ACT_emp.csv")
df_ACT
